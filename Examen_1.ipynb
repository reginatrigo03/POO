# %% [markdown]
# # Regina Trigo Zamora
# # 1er Parcial

# %%
import numpy as np

# %%
# 1. Consideramos el siguiente arreglo
# Debemos utilizar numpy para el arreglo
x=np.arange(10)

# %%
# 2. Realiza una segmentación para mostrar los valores de 4 a 7
segmento = x[4:8]

# %%
print(segmento)
# Out:
# [4 5 6 7]

# %%
# 3. Usa el atributo np.split(x,[3,6]). Para x1, x2,x2 = np.split(x,[3,6]). ¿Qué valores te muestra?
x1, x2, x3 = np.split(x,[3,6])

# %%
print('x1',x1)
print('x2',x2)
print('x3',x3)
# Out:
# x1 [0 1 2]
# x2 [3 4 5]
# x3 [6 7 8 9]

# %%
import pandas as pd

# %%
 # 4.Considera la siguiente base de datos:
 data = pd.DataFrame({'Country':    ['Russia','Colombia','Chile','Equador','Nigeria'],'Rank':[121,40,100,130,11]})

# %%
data
# Out:
#              uno  dos  tres  cuatro
# Veracruz       0    1     2       3
# Tampico        4    5     6       7
# Guadalajara    8    9    10      11

# %%
# 5.Del dataframe anterior, usa el atributo .info(). ¿Qué valores obtienes?
# Esta función muestra la información que se tiene de la base de nuestro data frame
# Nos dice que la columna "country" contiene objetos-texto, la columna "rank" contiene números enteros
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   k1      7 non-null      object
#  1   k2      7 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 240.0+ bytes

# %%
# 6.Considera la siguiente base de datos:
data = pd.DataFrame({'k1':['one']*3 + ['two']*4, 'k2':[3,2,1,3,3,4,4]})
# La columna de "k1" se suma 2 multiplicaciones (one * 3) y (dos * 4)
# La columna de "k2" se esta asignando dichos números enteros a esa columna, y no se esta haciendo ninguna operación

# %%
# solo se imprime el diccionario (ya tenemos dataframe)
print(data)
# Out:
#     k1  k2
# 0  one   3
# 1  one   2
# 2  one   1
# 3  two   3
# 4  two   3
# 5  two   4
# 6  two   4

# %%
# 7.Explica qué operación realiza el atributo .drop.duplicate()
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   3
# 1  one   2
# 2  one   1
# 3  two   3
# 5  two   4

# %%
# 8.Explica, cuidadosamente, el data frame:
data = pd.DataFrame(np.arange(12).reshape((3, 4)),index=['CDMX', 'Guanajuato', 'Puebla'],columns=['uno', 'dos', 'tres', 'cuatro'])

# %%
print(data)
# - Se crea un arreglo: números del 0 al 11 (con np.arange(12))
# - Hace que el arreglo sea de 3 filas y 4 columnas (.reshape((3,4)))
# - Nos muestra el nombre que se le va a asginar a cada fila (index=['CDMX', 'Guanajuato', 'Puebla'])
# - Nos dice el nombre que se le va a asginar a cada columna (columns=['uno', 'dos', 'tres', 'cuatro'])
# Out:
#             uno  dos  tres  cuatro
# CDMX          0    1     2       3
# Guanajuato    4    5     6       7
# Puebla        8    9    10      11

# %%
# 9. Del dataframe anterior, renombre las etiquetas que provee Python sobre los renglones
# Se vuelven a asignar valores
data = pd.DataFrame(np.arange(12).reshape((3, 4)),index=['Veracruz', 'Tampico', 'Guadalajara'],columns=['uno', 'dos', 'tres', 'cuatro'])

# %%
print(data)
# Out:
#              uno  dos  tres  cuatro
# Veracruz       0    1     2       3
# Tampico        4    5     6       7
# Guadalajara    8    9    10      11

# %%
# 10.Explica el siguiente código:
# "key1" y "key 2" son 2 columnas qe tienen listas con 5 valores
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'], 'key2' : ['one', 'two', 'one', 'two', 'one'], 'data1' : np.random.randn(5),'data2' : np.random.randn(5)})
# "data1" y "data2" son para la tercera y cuarta columna que contienen lista de números aleatorios
# 5 números usando np.random.randn(5)

# %%
print(df)
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.881285  0.711793
# 1    a  two  1.535719  0.326432
# 2    b  one  1.068669 -1.486168
# 3    b  two -1.560712 -0.724697
# 4    a  one  1.415677  0.706300

# %%
df.drop(columns='key2')
# Quitar columna no deseada
# Out:
#   key1     data1     data2
# 0    a  0.881285  0.711793
# 1    a  1.535719  0.326432
# 2    b  1.068669 -1.486168
# 3    b -1.560712 -0.724697
# 4    a  1.415677  0.706300

# %%
# Nuevo nombre a renglones
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'], 'key2' : ['one', 'two', 'one', 'two', 'one'], 'data1' : np.random.randn(5),'data2' : np.random.randn(5)},
                  index=['Year0','Year1','Year2','Year3','Year4'])

# %%
print(df)
# Out:
#       key1 key2     data1     data2
# Year0    a  one -1.865598 -0.280396
# Year1    a  two  2.115146 -1.125762
# Year2    b  one  0.432872 -1.198142
# Year3    b  two -1.373185  0.092513
# Year4    a  one -0.146327 -0.638462

# %%
df.describe()
# Datos en columnas "data1" y "data2"
# Cada media
# Desviación estándar
# Mínimos y máximos
# Valor donde encuentran los cuartiles
# Out:
#           data1     data2
# count  5.000000  5.000000
# mean  -0.167419 -0.630050
# std    1.573895  0.550655
# min   -1.865598 -1.198142
# 25%   -1.373185 -1.125762
# 50%   -0.146327 -0.638462
# 75%    0.432872 -0.280396
# max    2.115146  0.092513
