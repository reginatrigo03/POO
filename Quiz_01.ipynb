# %% [markdown]
# # Regina Trigo Zamora
# # Quiz 1

# %%
QUIZ_01 = { "A": [7, 1.6, 4, 10, 4.5],
          "B": [9.2, 2.4, 21, 30, 3.5],
          "C": [8, 1.7, 32, 40, 2.5] }

# %%
print(QUIZ_01)
# Out:
# {'A': [7, 1.6, 4, 10, 4.5], 'B': [9.2, 2.4, 21, 30, 3.5], 'C': [8, 1.7, 32, 40, 2.5]}

# %%
import pandas as pd

# %%
Valores = pd.DataFrame(QUIZ_01, index = ["Primero", "Segundo", "Tercero", "Cuarto", "Quinto"])
Valores
# Out:
#             A     B     C
# Primero   7.0   9.2   8.0
# Segundo   1.6   2.4   1.7
# Tercero   4.0  21.0  32.0
# Cuarto   10.0  30.0  40.0
# Quinto    4.5   3.5   2.5

# %%
type(Valores)
# Out:
# pandas.core.frame.DataFrame

# %%
Valores.ndim
# Out:
# 2

# %%
Valores["A"]
# Out:
# Primero    7.0
# Segundo    1.6
# Tercero    4.0
# Name: A, dtype: float64

# %%
Valores["B"]
# Out:
# Primero     9.2
# Segundo     2.4
# Tercero    21.0
# Name: B, dtype: float64

# %%
Valores.iloc[0]
# Out:
# A    7.0
# B    9.2
# C    8.0
# D    5.6
# E    9.0
# Name: Primero, dtype: float64

# %%
Valores.iloc[0:2]
# Out:
#            A    B    C
# Primero  7.0  9.2  8.0
# Segundo  1.6  2.4  1.7

# %%
Valores.iloc[1:3]
# Out:
#            A     B     C
# Segundo  1.6   2.4   1.7
# Tercero  4.0  21.0  32.0

# %%
Valores.iloc[2:3]
# Out:
#            A     B     C
# Tercero  4.0  21.0  32.0

# %%
import numpy as np
import pandas as pd

# %%
lista_1=np.random.randint(-1,2,size=5)

# %%
lista_1
# Out:
# array([ 1,  1, -1,  1,  1])

# %%
lista_2=np.random.randint(-30,50,size=5)

# %%
lista_2
# Out:
# array([ 6, 33,  4, 14,  7])

# %%
lista_3=np.random.randint(-45,70,size=5)

# %%
lista_3
# Out:
# array([49, 26, 39,  1, -3])

# %%
diccionario={'CapSmall':lista_1,'CapMedium':lista_2, 'CapLarge':lista_3}

# %%
diccionario
# Out:
# {'CapSmall': array([ 1,  1, -1,  1,  1]),
#  'CapMedium': array([ 6, 33,  4, 14,  7]),
#  'CapLarge': array([49, 26, 39,  1, -3])}

# %%
df=pd.DataFrame(diccionario)

# %%
df
# Out:
#    CapSmall  CapMedium  CapLarge
# 0         1          6        49
# 1         1         33        26
# 2        -1          4        39
# 3         1         14         1
# 4         1          7        -3

# %%
dfindex = pd.DataFrame(diccionario,index = ["A", "B", "C", "D", "E"])

# %%
dfindex
# Out:
#    CapSmall  CapMedium  CapLarge
# A         1          6        49
# B         1         33        26
# C        -1          4        39
# D         1         14         1
# E         1          7        -3

# %%
dfindex.describe()
# Out:
#        CapSmall  CapMedium   CapLarge
# count  5.000000   5.000000   5.000000
# mean   0.600000  12.800000  22.400000
# std    0.894427  11.903781  22.908514
# min   -1.000000   4.000000  -3.000000
# 25%    1.000000   6.000000   1.000000
# 50%    1.000000   7.000000  26.000000
# 75%    1.000000  14.000000  39.000000
# max    1.000000  33.000000  49.000000

# %%
df2=dfindex.drop(columns='CapSmall')
df2.iloc[1:3]
# Out:
#    CapMedium  CapLarge
# B         33        26
# C          4        39

# %%
df2.mean()
# Out:
# CapMedium    12.8
# CapLarge     22.4
# dtype: float64

# %%
mayores = df2[df2['CapLarge']>10]

# %%
mayores
# Out:
#    CapMedium  CapLarge
# A          6        49
# B         33        26
# C          4        39

# %%
mayores.shape
# Out:
# (3, 2)

# %%
items=diccionario.items()

# %%
items
# Out:
# dict_items([('CapSmall', array([ 1,  1, -1,  1,  1])), ('CapMedium', array([ 6, 33,  4, 14,  7])), ('CapLarge', array([49, 26, 39,  1, -3]))])

# %%
type(items)
# Out:
# dict_items

# %%
df=pd.DataFrame(diccionario)

# %%
df
# Out:
#    CapSmall  CapMedium  CapLarge
# 0         1          6        49
# 1         1         33        26
# 2        -1          4        39
# 3         1         14         1
# 4         1          7        -3
